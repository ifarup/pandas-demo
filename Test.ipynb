# %% [markdown]
# # Overskrift
#
# Så kan vi skrive tekst her hvis vi vil. $f(x) = x^2$

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(0, 1)
y = np.sin(2 * np.pi * x)

# %%
plt.plot(x, y)
plt.plot(x, 2 * y)
